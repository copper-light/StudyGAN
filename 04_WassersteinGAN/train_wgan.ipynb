# %%
from trainCNN import new_train, resume_train
# Out:
# cuda

# %%
new_train()
# Out:
#   0%|          | 0/60 [00:00<?, ?it/s]D:\Programming\workspace_python\StudyGAN\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# D:\Programming\workspace_python\StudyGAN\.venv\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...
#  15%|█▌        | 9/60 [04:19<23:53, 28.10s/it, Epoch 10, 755/3750, dis_loss: 0.0006, gen_loss: -0.0457]
