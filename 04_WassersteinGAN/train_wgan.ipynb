# %%
from trainCNN import train
# Out:
# cuda

# %%
train()
# Out:
#   0%|                                                                                           | 0/40 [00:00<?, ?it/s]D:\Programming\workspace_python\StudyGAN\.venv\Lib\site-packages\numpy\_core\fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# D:\Programming\workspace_python\StudyGAN\.venv\Lib\site-packages\numpy\_core\_methods.py:144: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# ...
#  35%|███████████▉                      | 14/40 [05:40<09:51, 22.75s/it, 3750/3750, dis_loss: -9.0509, gen_loss: 1.2037]
